# %%
# Linear Regression Example in Python
# pip install pandas scikit-learn
# !pip install pandas scikit-learn
# Out:
# Collecting pandas
#   Using cached pandas-2.3.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (91 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/marthala/mydata/00_learning/courses/training/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: six>=1.5 in /Users/marthala/mydata/00_learning/courses/training/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Using cached pandas-2.3.3-cp312-cp312-macosx_10_13_x86_64.whl (11.6 MB)
# Downloading scikit_learn-1.8.0-cp312-cp312-macosx_10_13_x86_64.whl (8.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 11.2 MB/s  0:00:00 eta 0:00:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Using cached numpy-2.3.5-cp312-cp312-macosx_14_0_x86_64.whl (6.6 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.16.3-cp312-cp312-macosx_14_0_x86_64.whl (23.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.6/23.6 MB 11.5 MB/s  0:00:02 eta 0:00:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Installing collected packages: pytz, tzdata, threadpoolctl, numpy, joblib, scipy, pandas, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8/8 [scikit-learn] [scikit-learn]
# Successfully installed joblib-1.5.3 numpy-2.3.5 pandas-2.3.3 pytz-2025.2 scikit-learn-1.8.0 scipy-1.16.3 threadpoolctl-3.6.0 tzdata-2025.3

# %%
# Import necessary libraries
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# load the dataset
data = pd.read_csv('housing_rents.csv')
# display the first few rows of the dataset
print(data.head())
# Out:
#    size  rent  location
# 0   500  1500         1
# 1   700  2000         2
# 2   900  2200         3
# 3  1100  2400         4
# 4  1300  2600         5

# %%
# Prepare the data
X = data[['size']]
y = data['rent']

# Create and train the model
model = LinearRegression()
model.fit(X, y)
y_pred = model.predict(X)

# %%
# Results
print("Slope:", model.coef_[0])
print("Intercept:", model.intercept_)
# Out:
# Slope: 1.2999999999999996
# Intercept: 970.0000000000005

# %%
predicted_rents = model.predict([[900]])
print(f'Predicted rent : ${predicted_rents[0]}')
# Out:
# Predicted rent : $2140.0
# /Users/marthala/mydata/00_learning/courses/training/.venv/lib/python3.12/site-packages/sklearn/utils/validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
